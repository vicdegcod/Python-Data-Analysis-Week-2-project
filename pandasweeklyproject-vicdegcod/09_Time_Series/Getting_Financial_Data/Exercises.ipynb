# %% [markdown]
# # Getting Financial Data - Google Finance

# %% [markdown]
# ### Introduction:
#
# This time you will get data from a website.
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)

# %%
import yfinance as yf

start = "2015-01-01"
end = "2026-08-05"

stocks = ["AAPL", "TSLA", "IBM"]

data = yf.download(stocks, start=start, end=end)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
# Create the time range
start = pd.Timestamp("2015-01-01")
end = pd.Timestamp.today()

print("Start:", start)
print("End:", end)
# Out:
# Start: 2015-01-01 00:00:00
# End: 2026-08-05 18:35:58.148687

# %% [markdown]
# ### Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks

# %%
import yfinance as yf

# %%
stocks = ["AAPL", "TSLA", "TWTR", "IBM", "LNKD"]

# %%
import yfinance as yf

data = yf.download(stocks, start=start, end=end)
# Out:
# [*********************100%***********************]  3 of 3 completed

# %% [markdown]
# ### Step 4. Read the data from google, assign to df and print it

# %%
import yfinance as yf

# Download stock data
df = yf.download(stocks, start=start, end=end)

# Display the DataFrame
print(df)
# Out:
# [*******************   40%                       ]  2 of 5 completed$LNKD: possibly delisted; no price data found  (1d 2015-01-01 -> 2026-08-05)
# [**********************60%****                   ]  3 of 5 completedHTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: TWTR"}}}
# $TWTR: possibly delisted; no timezone found
# [*********************100%***********************]  5 of 5 completed
#
# 2 Failed downloads:
# ['LNKD']: possibly delisted; no price data found  (1d 2015-01-01 -> 2026-08-05)
# ['TWTR']: possibly delisted; no timezone found
# Price      Adj Close            Close                                    \
# Ticker          LNKD TWTR        AAPL         IBM LNKD        TSLA TWTR
# Date
# 2015-01-02       NaN  NaN   24.192608   96.853943  NaN   14.620667  NaN
# 2015-01-05       NaN  NaN   23.511061   95.329956  NaN   14.006000  NaN
# 2015-01-06       NaN  NaN   23.513273   93.274055  NaN   14.085333  NaN
# ...

# %% [markdown]
# ### Step 5.  What is the type of structure of df ?

# %%
type(df)
# Out:
# pandas.DataFrame

# %% [markdown]
# ### Step 6. Print all the Items axis values
# #### To learn more about the Panel structure go to [documentation](http://pandas.pydata.org/pandas-docs/stable/dsintro.html#panel)

# %%
# Print row index (axis 0)
print(df.index)

# Print column labels (axis 1)
print(df.columns)
# Out:
# DatetimeIndex(['2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#                '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13',
#                '2015-01-14', '2015-01-15',
#                ...
#                '2026-07-22', '2026-07-23', '2026-07-24', '2026-07-27',
#                '2026-07-28', '2026-07-29', '2026-07-30', '2026-07-31',
#                '2026-08-03', '2026-08-04'],
#               dtype='datetime64[s]', name='Date', length=2913, freq=None)
# MultiIndex([('Adj Close', 'LNKD'),
#             ('Adj Close', 'TWTR'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'IBM'),
#             (    'Close', 'LNKD'),
#             (    'Close', 'TSLA'),
#             (    'Close', 'TWTR'),
#             (     'High', 'AAPL'),
#             (     'High',  'IBM'),
#             (     'High', 'LNKD'),
#             (     'High', 'TSLA'),
#             (     'High', 'TWTR'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'IBM'),
# ...

# %% [markdown]
# ### Step 7. Good, now we know  the data avaiable. Create a dataFrame called vol, with the Volume values.

# %%
vol = df["Volume"]
vol
# Out:
# Ticker           AAPL      IBM  LNKD      TSLA  TWTR
# Date
# 2015-01-02  212818400  5779673   NaN  71466000   NaN
# 2015-01-05  257142000  5104898   NaN  80527500   NaN
# 2015-01-06  263188400  6429448   NaN  93928500   NaN
# 2015-01-07  160423600  4918083   NaN  44526000   NaN
# 2015-01-08  237458000  4431693   NaN  51637500   NaN
# ...               ...      ...   ...       ...   ...
# 2026-07-29   56090800  8806700   NaN  39478000   NaN
# 2026-07-30   74817800  9675200   NaN  38005400   NaN
# 2026-07-31  132489100  9093600   NaN  36630600   NaN
# 2026-08-03   75052000  7974700   NaN  38281400   NaN
# 2026-08-04   67882600  7526900   NaN  33196800   NaN
#
# [2913 rows x 5 columns]

# %% [markdown]
# ### Step 8. Aggregate the data of Volume to weekly
# #### Hint: Be careful to not sum data from the same week of 2015 and other years.

# %%
vol_weekly = vol.resample("W").sum()
vol_weekly.head()
# Out:
# Ticker            AAPL       IBM  LNKD       TSLA  TWTR
# Date
# 2015-01-04   212818400   5779673   0.0   71466000   0.0
# 2015-01-11  1133010000  25578884   0.0  340644000   0.0
# 2015-01-18  1216906400  24329751   0.0  461988000   0.0
# 2015-01-25   794948000  32682062   0.0  243175500   0.0
# 2015-02-01  1863370800  34442689   0.0  235803000   0.0

# %% [markdown]
# ### Step 9. Find all the volume traded in the year of 2015

# %%
# Total volume traded in 2015
vol_2015 = vol.loc["2015"].sum()

print(vol_2015)
# Out:
# Ticker
# AAPL    5.226420e+10
# IBM     1.156439e+09
# LNKD    0.000000e+00
# TSLA    1.632327e+10
# TWTR    0.000000e+00
# dtype: float64

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %% [markdown]
# Step 10. Which stock had the highest total trading volume over the entire dataset?

# %%
# Calculate the total trading volume for each stock
total_volume = vol.sum()

# Display the total volume for each stock
print(total_volume)

# Find the stock with the highest total volume
most_traded = total_volume.idxmax()
highest_volume = total_volume.max()

print(f"The most traded stock was {most_traded} with a total volume of {highest_volume:,}.")
# Out:
# Ticker
# AAPL    3.156914e+11
# IBM     1.447053e+10
# LNKD    0.000000e+00
# TSLA    3.152414e+11
# TWTR    0.000000e+00
# dtype: float64
# The most traded stock was AAPL with a total volume of 315,691,375,400.0.
